# %% [markdown]
# <a href="https://colab.research.google.com/github/lumiereisrael7/DL-Learning/blob/main/Lecon_2_Vecteurs_Matrices_Tenseurs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
data = np.array(3) #scalaire

# %%
data.shape
# Out:
# ()

# %%
data.ndim
# Out:
# 0

# %%
maison = [3, 15, 30]

# %%
maison = np.array(maison)

# %%
maison.shape
# Out:
# (3,)

# %%
maison.ndim #vecteur = ensemble de scalaire
# Out:
# 1

# %%
quartier = [
    [4, 20, 2],
    [3, 15, 30],
    [2, 65, 60],
    [3, 18, 15]
]

# %%
quartier = np.array(quartier)

# %%
quartier.shape
# Out:
# (4, 3)

# %%
quartier.ndim #matrice = ensemble de vecteur
# Out:
# 2

# %%
quartier
# Out:
# array([[ 4, 20,  2],
#        [ 3, 15, 30],
#        [ 2, 65, 60],
#        [ 3, 18, 15]])

# %%
ville = [
    [
       [ 4, 20,  2],
       [ 3, 15, 30],
       [ 2, 65, 60],
       [ 3, 18, 15] 
    ], 
    [
        [ 4, 12,  2],
        [ 3, 15, 30],
        [ 2, 45, 60],
        [ 3, 18, 15]
    ]
]

# %%
ville = np.array(ville)

# %%
ville.shape
# Out:
# (2, 4, 3)

# %%
ville.ndim # ensembre de matrice, tenseur de dimensions 3
# Out:
# 3

# %%
ville
# Out:
# array([[[ 4, 20,  2],
#         [ 3, 15, 30],
#         [ 2, 65, 60],
#         [ 3, 18, 15]],
#
#        [[ 4, 12,  2],
#         [ 3, 15, 30],
#         [ 2, 45, 60],
#         [ 3, 18, 15]]])

# %%
from matplotlib import image
import matplotlib.pyplot as plt

# %%
chien = image.imread('chien.jpg')
chien
# Out:
# array([[[140, 147, 106],
#         [140, 147, 106],
#         [140, 147, 106],
#         ...,
#         [104,  79,  49],
#         [106,  81,  51],
#         [108,  83,  53]],
#
#        [[140, 147, 106],
#         [140, 147, 106],
#         [140, 147, 106],
#         ...,
#         [104,  79,  49],
#         [106,  81,  51],
#         [108,  83,  53]],
#
#        [[140, 147, 106],
#         [140, 147, 106],
#         [141, 148, 107],
#         ...,
#         [102,  79,  48],
#         [105,  82,  51],
#         [107,  84,  53]],
#
#        ...,
#
#        [[169, 194,  64],
#         [166, 191,  61],
#         [164, 186,  59],
#         ...,
#         [170, 178,  66],
#         [168, 176,  64],
#         [168, 176,  64]],
#
#        [[172, 195,  63],
#         [169, 192,  60],
#         [164, 187,  57],
#         ...,
#         [170, 178,  67],
#         [168, 176,  65],
#         [168, 176,  65]],
#
#        [[171, 195,  59],
#         [168, 191,  57],
#         [163, 186,  54],
# ...

# %%
chien.shape # tenseur de dimensions 3
# Out:
# (582, 932, 3)

# %%
plt.imshow(chien)

# %%
plt.imshow(chien[:, :, 0])

# %%
plt.imshow(chien[:, :, 1])

# %%
plt.imshow(chien[:, :, 2])

# %%
def double(x):
  return 2 * x

# %%
double(5)
# Out:
# 10

# %%
double(maison)
# Out:
# array([ 6, 30, 60])
